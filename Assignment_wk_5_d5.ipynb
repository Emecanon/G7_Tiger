# %% [markdown]
# # Q1:
#     a) Create online Repo with a name of your choice
#     b) Clone the repo onto the github desktop
#     c) Using a dataset of your choice create a bar chart, pie chart and histogram. Apply seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
Data = sns.load_dataset('tips')
df = pd.DataFrame(Data)
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
gender_counts = Data['sex'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Gender Distribution in Tips Dataset")
plt.axis('equal')
plt.legend()
plt.show()

sns.barplot(x="day", y="total_bill", data=Data, palette='coolwarm')
plt.title("Total Bill by Day")
plt.xlabel("Day of the Week")
plt.ylabel("Total Bill ($)")
plt.show()


sns.displot(Data["total_bill"],kde=True)
plt.title("Total Bill by day")
plt.xlabel("Sex")
plt.ylabel("Total Bill ($)")
plt.show()
# Out:
# C:\Users\T29171430\AppData\Local\Temp\ipykernel_22876\3437947504.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day", y="total_bill", data=Data, palette='coolwarm')

# %% [markdown]
# # Q2:
#     a) Create a set with names of your group members
#     b) Create a dictionary of the details of the members
#     c) Updated the dictionary with the details of gender.
#     d) Push the changes to the remote repo.

# %%
G7_Tiger = {
    "First_Name":['Erick','Damacline','Adrian'],
    "Last_Name":['Masaki','Machani','Gitamu'],
    "Department":['Finance','SIRM','SIRM'],
    "Unit":['Revenue','Statistics','Research'],
    
}
print(G7_Tiger)
# Out:
# {'First_Name': ['Erick', 'Damacline', 'Adrian'], 'Last_Name': ['Masaki', 'Machani', 'Gitamu'], 'Department': ['Finance', 'SIRM', 'SIRM'], 'Unit': ['Revenue', 'Statistics', 'Research']}

# %%
G7_Tiger["Gender"] =['Male','Female','Male']

import pandas as pd
full_names = []

for i in range(len(G7_Tiger["First_Name"])):
    first = G7_Tiger["First_Name"][i]
    last = G7_Tiger["Last_Name"][i]
    full_names.append(f"{first} {last}")

G7_Tiger['Full_Name']= full_names

# %%
G7_Tiger
# Out:
# {'First_Name': ['Erick', 'Damacline', 'Adrian'],
#  'Last_Name': ['Masaki', 'Machani', 'Gitamu'],
#  'Department': ['Finance', 'SIRM', 'SIRM'],
#  'Unit': ['Revenue', 'Statistics', 'Research'],
#  'Gender': ['Male', 'Female', 'Male'],
#  'Full_Name': ['Erick Masaki', 'Damacline Machani', 'Adrian Gitamu']}

# %%
df=pd.DataFrame(G7_Tiger)
df
# Out:
#   First_Name Last_Name Department        Unit  Gender          Full_Name
# 0      Erick    Masaki    Finance     Revenue    Male       Erick Masaki
# 1  Damacline   Machani       SIRM  Statistics  Female  Damacline Machani
# 2     Adrian    Gitamu       SIRM    Research    Male      Adrian Gitamu
